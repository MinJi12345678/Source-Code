# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 9월 6일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230906.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC SCLAS                                              GOODS  \
# 0   여성복   원피스  롱원피스           여름나시/롱원피스/바캉스룩원피스/리넨원피스/여름원피스/리넨나시/나시원피스
# 1   여성복   원피스  롱원피스  맥시원피스/롱원피스/바캉스룩원피스/리넨원피스/어깨끈원피스/여름원피스/리넨나시/나시원...
# 2   여성복   원피스  롱원피스  러플원피스/롱원피스/허리끈원피스/칼라원피스/프릴원피스/여름원피스/셔츠원피스/레이스원...
#
#                         COLOR PRPOS      QLFMT PATT      CHARTR      DETL  \
# 0               블랙/네이비/블루/베이지   NaN         리넨  NaN         NaN  맥시/워싱/나시
# 1                      블랙/베이지   NaN  실크/리넨/레이온  NaN         NaN     맥시/나시
# 2  퍼플/베이지/핑크/그린/라이트블루/블랙/아이보리   NaN         코튼  NaN  고급스러운/비침방지    펀칭/스트링
#
#    BEM   SLPR  LATST
# 0  NaN  31500      0
# 1  NaN  33900      1
# 2  NaN  25440      0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425077 entries, 0 to 425076
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   425077 non-null  object
#  1   MLSFC   425077 non-null  object
#  2   SCLAS   425077 non-null  object
#  3   GOODS   349031 non-null  object
#  4   COLOR   350550 non-null  object
#  5   PRPOS   123833 non-null  object
#  6   QLFMT   370021 non-null  object
#  7   PATT    195804 non-null  object
#  8   CHARTR  263720 non-null  object
#  9   DETL    314430 non-null  object
#  10  BEM     15431 non-null   object
#  11  SLPR    425077 non-null  int64
#  12  LATST   425077 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 42.2+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      76046
# COLOR      74527
# PRPOS     301244
# QLFMT      55056
# PATT      229273
# CHARTR    161357
# DETL      110647
# BEM       409646
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC SCLAS                                              GOODS  \
# 0   원피스  롱원피스           여름나시/롱원피스/바캉스룩원피스/리넨원피스/여름원피스/리넨나시/나시원피스
# 1   원피스  롱원피스  맥시원피스/롱원피스/바캉스룩원피스/리넨원피스/어깨끈원피스/여름원피스/리넨나시/나시원...
# 2   원피스  롱원피스  러플원피스/롱원피스/허리끈원피스/칼라원피스/프릴원피스/여름원피스/셔츠원피스/레이스원...
# 3   원피스  롱원피스                                   도트원피스/맥시원피스/롱원피스
# 4   원피스  롱원피스                       맥시원피스/플리츠원피스/롱원피스/봄원피스/여름원피스
#
#                         COLOR      QLFMT    SLPR  LATST
# 0               블랙/네이비/블루/베이지         리넨   31500      0
# 1                      블랙/베이지  실크/리넨/레이온   33900      1
# 2  퍼플/베이지/핑크/그린/라이트블루/블랙/아이보리         코튼   25440      0
# 3                      블랙/화이트      폴리에스터  107640      5
# 4                          블랙      폴리에스터  123240      4

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    74527
# QLFMT    55056
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 308966 entries, 0 to 425076
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   308966 non-null  object
#  1   SCLAS   308966 non-null  object
#  2   GOODS   308966 non-null  object
#  3   COLOR   308966 non-null  object
#  4   QLFMT   308966 non-null  object
#  5   SLPR    308966 non-null  int64
#  6   LATST   308966 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.9+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_09_06')

df1.head(3)
# Out:
#          Time MLSFC SCLAS                                              GOODS  \
# 1  2023_09_06   원피스  롱원피스  맥시원피스/롱원피스/바캉스룩원피스/리넨원피스/어깨끈원피스/여름원피스/리넨나시/나시원...
# 3  2023_09_06   원피스  롱원피스                                   도트원피스/맥시원피스/롱원피스
# 4  2023_09_06   원피스  롱원피스                       맥시원피스/플리츠원피스/롱원피스/봄원피스/여름원피스
#
#     COLOR      QLFMT    SLPR  LATST
# 1  블랙/베이지  실크/리넨/레이온   33900      1
# 3  블랙/화이트      폴리에스터  107640      5
# 4      블랙      폴리에스터  123240      4

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#          Time category_middle_desc category_small_desc  \
# 1  2023_09_06                  원피스                롱원피스
# 3  2023_09_06                  원피스                롱원피스
# 4  2023_09_06                  원피스                롱원피스
#
#                                                 item   color   material  \
# 1  맥시원피스/롱원피스/바캉스룩원피스/리넨원피스/어깨끈원피스/여름원피스/리넨나시/나시원...  블랙/베이지  실크/리넨/레이온
# 3                                   도트원피스/맥시원피스/롱원피스  블랙/화이트      폴리에스터
# 4                       맥시원피스/플리츠원피스/롱원피스/봄원피스/여름원피스      블랙      폴리에스터
#
#    sale_price  recent_sale_count
# 1       33900                  1
# 3      107640                  5
# 4      123240                  4

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230906.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

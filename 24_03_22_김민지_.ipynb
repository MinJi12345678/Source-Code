# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 8월 02일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230802.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc  \
# 0                 여성복                  원피스               셔츠원피스
# 1                 여성복                  원피스               셔츠원피스
# 2                 여성복                  원피스               셔츠원피스
#
#                                             item            color  \
# 0                                         하객룩원피스      블랙/아이보리/베이지
# 1  롱원피스/맥시원피스/롱랩원피스/벨트원피스/언발원피스/매듭원피스/랩원피스/셔츠원피스              NaN
# 2                              롱원피스/맥시원피스/브이넥원피스  차콜/아이보리/그레이/베이지
#
#                        use material print_pattern characteristic     detail  \
# 0  하객룩/돌잔치룩/돌잔치/결혼식/웨딩/상견례    폴리에스터           NaN           빅사이즈        NaN
# 1                      NaN    폴리에스터           NaN           유니크한     랩/드레이프
# 2                      임산부      나일론          체크/별            깔끔한  스트링/워싱/맥시
#
#    age weight season sensibility  sale_price  recent_sale_count
# 0  NaN    NaN    NaN          청순       59000                  0
# 1  NaN    NaN    NaN         NaN       94800                  0
# 2  NaN    NaN    NaN         NaN       64900                  0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423615 entries, 0 to 423614
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   423615 non-null  object
#  1   category_middle_desc  423615 non-null  object
#  2   category_small_desc   423615 non-null  object
#  3   item                  345189 non-null  object
#  4   color                 349488 non-null  object
#  5   use                   123449 non-null  object
#  6   material              368798 non-null  object
#  7   print_pattern         196050 non-null  object
#  8   characteristic        263982 non-null  object
#  9   detail                313664 non-null  object
#  10  age                   1792 non-null    object
#  11  weight                24703 non-null   object
#  12  season                382 non-null     object
#  13  sensibility           15317 non-null   object
#  14  sale_price            423615 non-null  int64
#  15  recent_sale_count     423615 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 51.7+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                     78426
# color                    74127
# use                     300166
# material                 54817
# print_pattern           227565
# characteristic          159633
# detail                  109951
# age                     421823
# weight                  398912
# season                  423233
# sensibility             408298
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스               셔츠원피스
# 1                  원피스               셔츠원피스
# 2                  원피스               셔츠원피스
# 3                  원피스               셔츠원피스
# 4                  원피스               셔츠원피스
#
#                                             item              color  material  \
# 0                                         하객룩원피스        블랙/아이보리/베이지     폴리에스터
# 1  롱원피스/맥시원피스/롱랩원피스/벨트원피스/언발원피스/매듭원피스/랩원피스/셔츠원피스                NaN     폴리에스터
# 2                              롱원피스/맥시원피스/브이넥원피스    차콜/아이보리/그레이/베이지       나일론
# 3    롱원피스/플레어원피스/반팔원피스/반팔롱원피스/홀터넥원피스/밴딩원피스/여름원피스  네이비/차콜/아이보리/라이트블루        코튼
# 4    A라인원피스/롱원피스/하객룩원피스/여름셔츠/여름셔츠원피스/여름원피스/셔츠원피스   블랙/네이비/라이트블루/베이지  코튼/폴리에스터
#
#    sale_price  recent_sale_count
# 0       59000                  0
# 1       94800                  0
# 2       64900                  0
# 3       47000                  0
# 4       26800                  0

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc        0
# category_small_desc         0
# item                        0
# color                   74127
# material                54817
# sale_price                  0
# recent_sale_count           0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307934 entries, 0 to 423614
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  307934 non-null  object
#  1   category_small_desc   307934 non-null  object
#  2   item                  307934 non-null  object
#  3   color                 307934 non-null  object
#  4   material              307934 non-null  object
#  5   sale_price            307934 non-null  int64
#  6   recent_sale_count     307934 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.8+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_08_02')

df1.head(3)
# Out:
#           Time category_middle_desc category_small_desc  \
# 15  2023_08_02                  원피스               셔츠원피스
# 55  2023_08_02                  원피스               데님원피스
# 60  2023_08_02                  원피스               데님원피스
#
#                                                  item  \
# 15            롱원피스/베이식원피스/냉장고원피스/반팔롱원피스/빅사이즈원피스/여름원피스
# 55  칼라원피스/캐주얼원피스/빅사이즈원피스/오버핏원피스/박시원피스/데님원피스/여름원피스/...
# 60                                        미디원피스/데님원피스
#
#                       color         material  sale_price  recent_sale_count
# 15  블랙/옐로우/그레이/민트/베이지/카키/핑크  레이온/폴리에스터/실크/스판       19700                  1
# 55                  화이트/베이지               코튼       61000                  2
# 60           화이트/아이보리/라이트블루         코튼/폴리에스터       24900                  3

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230802.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

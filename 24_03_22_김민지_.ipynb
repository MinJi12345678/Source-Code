# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 9월 13일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230913.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC SCLAS                                              GOODS  \
# 0   여성복   원피스  롱원피스           리넨원피스/여름나시/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름원피스
# 1   여성복   원피스  롱원피스  셔츠원피스/칼라원피스/러플원피스/프릴원피스/레이스원피스/리본원피스/펀칭원피스/롱원피...
# 2   여성복   원피스  롱원피스                                   롱원피스/맥시원피스/도트원피스
#
#                         COLOR PRPOS  QLFMT   PATT      CHARTR      DETL  BEM  \
# 0               블랙/블루/네이비/베이지   NaN     리넨    NaN         NaN  워싱/맥시/나시  NaN
# 1  베이지/블랙/그린/퍼플/라이트블루/핑크/아이보리   NaN     코튼    NaN  고급스러운/비침방지    스트링/펀칭  NaN
# 2                      블랙/화이트   NaN  폴리에스터  도트/도트         NaN       스트링  NaN
#
#      SLPR  LATST
# 0   31500      1
# 1   25440      1
# 2  107640      3

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427645 entries, 0 to 427644
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   427645 non-null  object
#  1   MLSFC   427645 non-null  object
#  2   SCLAS   427645 non-null  object
#  3   GOODS   351479 non-null  object
#  4   COLOR   352040 non-null  object
#  5   PRPOS   124073 non-null  object
#  6   QLFMT   372326 non-null  object
#  7   PATT    196576 non-null  object
#  8   CHARTR  264834 non-null  object
#  9   DETL    315729 non-null  object
#  10  BEM     15360 non-null   object
#  11  SLPR    427645 non-null  int64
#  12  LATST   427645 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 42.4+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      76166
# COLOR      75605
# PRPOS     303572
# QLFMT      55319
# PATT      231069
# CHARTR    162811
# DETL      111916
# BEM       412285
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC SCLAS                                              GOODS  \
# 0   원피스  롱원피스           리넨원피스/여름나시/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름원피스
# 1   원피스  롱원피스  셔츠원피스/칼라원피스/러플원피스/프릴원피스/레이스원피스/리본원피스/펀칭원피스/롱원피...
# 2   원피스  롱원피스                                   롱원피스/맥시원피스/도트원피스
# 3   원피스  롱원피스                                      하객룩원피스/로맨틱원피스
# 4   원피스  롱원피스       칼라원피스/피로연원피스/하객룩원피스/정장원피스/롱원피스/여름원피스/베이비돌원피스
#
#                         COLOR  QLFMT    SLPR  LATST
# 0               블랙/블루/네이비/베이지     리넨   31500      1
# 1  베이지/블랙/그린/퍼플/라이트블루/핑크/아이보리     코튼   25440      1
# 2                      블랙/화이트  폴리에스터  107640      3
# 3                          네온  폴리에스터   33900      0
# 4              블랙/화이트/네이비/베이지  폴리에스터   59400     12

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    75605
# QLFMT    55319
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310301 entries, 0 to 427644
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   310301 non-null  object
#  1   SCLAS   310301 non-null  object
#  2   GOODS   310301 non-null  object
#  3   COLOR   310301 non-null  object
#  4   QLFMT   310301 non-null  object
#  5   SLPR    310301 non-null  int64
#  6   LATST   310301 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.9+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_10_04')

df1.head(3)
# Out:
#          Time MLSFC SCLAS                                              GOODS  \
# 0  2023_10_04   원피스  롱원피스           리넨원피스/여름나시/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름원피스
# 1  2023_10_04   원피스  롱원피스  셔츠원피스/칼라원피스/러플원피스/프릴원피스/레이스원피스/리본원피스/펀칭원피스/롱원피...
# 2  2023_10_04   원피스  롱원피스                                   롱원피스/맥시원피스/도트원피스
#
#                         COLOR  QLFMT    SLPR  LATST
# 0               블랙/블루/네이비/베이지     리넨   31500      1
# 1  베이지/블랙/그린/퍼플/라이트블루/핑크/아이보리     코튼   25440      1
# 2                      블랙/화이트  폴리에스터  107640      3

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#          Time category_middle_desc category_small_desc  \
# 0  2023_10_04                  원피스                롱원피스
# 1  2023_10_04                  원피스                롱원피스
# 2  2023_10_04                  원피스                롱원피스
#
#                                                 item  \
# 0           리넨원피스/여름나시/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름원피스
# 1  셔츠원피스/칼라원피스/러플원피스/프릴원피스/레이스원피스/리본원피스/펀칭원피스/롱원피...
# 2                                   롱원피스/맥시원피스/도트원피스
#
#                         color material  sale_price  recent_sale_count
# 0               블랙/블루/네이비/베이지       리넨       31500                  1
# 1  베이지/블랙/그린/퍼플/라이트블루/핑크/아이보리       코튼       25440                  1
# 2                      블랙/화이트    폴리에스터      107640                  3

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230913.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 7월 5일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230705.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc  \
# 0                 여성복                  원피스                롱원피스
# 1                 여성복                  원피스                롱원피스
# 2                 여성복                  원피스                롱원피스
#
#                                        item          color  use  material  \
# 0  리넨원피스/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름나시/여름원피스  네이비/블랙/베이지/블루  NaN        리넨
# 1                트위드원피스/로맨틱원피스/슬림원피스/하객룩원피스      블랙/베이지/골드  NaN   폴리에스터/울
# 2             베이식원피스/셔츠원피스/롱셔츠원피스/칼라원피스/롱셔츠    블랙/베이지/아이보리  NaN  코튼/폴리에스터
#
#   print_pattern characteristic    detail  age weight season sensibility  \
# 0           NaN            NaN  맥시/나시/워싱  NaN    NaN    NaN         NaN
# 1           NaN    여성스러운/고급스러운       NaN  NaN    NaN    NaN         NaN
# 2           NaN            NaN       루즈핏  NaN    NaN    NaN         NaN
#
#    sale_price  recent_sale_count
# 0       31500                  2
# 1       79500                  0
# 2       15800                  0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416487 entries, 0 to 416486
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   416487 non-null  object
#  1   category_middle_desc  416487 non-null  object
#  2   category_small_desc   416487 non-null  object
#  3   item                  337085 non-null  object
#  4   color                 342779 non-null  object
#  5   use                   119303 non-null  object
#  6   material              362769 non-null  object
#  7   print_pattern         192515 non-null  object
#  8   characteristic        259161 non-null  object
#  9   detail                306894 non-null  object
#  10  age                   1749 non-null    object
#  11  weight                23740 non-null   object
#  12  season                344 non-null     object
#  13  sensibility           14888 non-null   object
#  14  sale_price            416487 non-null  int64
#  15  recent_sale_count     416487 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 50.8+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                     79402
# color                    73708
# use                     297184
# material                 53718
# print_pattern           223972
# characteristic          157326
# detail                  109593
# age                     414738
# weight                  392747
# season                  416143
# sensibility             401599
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
# 3                  원피스                롱원피스
# 4                  원피스                롱원피스
#
#                                        item          color  material  \
# 0  리넨원피스/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름나시/여름원피스  네이비/블랙/베이지/블루        리넨
# 1                트위드원피스/로맨틱원피스/슬림원피스/하객룩원피스      블랙/베이지/골드   폴리에스터/울
# 2             베이식원피스/셔츠원피스/롱셔츠원피스/칼라원피스/롱셔츠    블랙/베이지/아이보리  코튼/폴리에스터
# 3                          맥시원피스/롱원피스/도트원피스        네이비/화이트     폴리에스터
# 4              플리츠원피스/맥시원피스/롱원피스/봄원피스/여름원피스             블랙     폴리에스터
#
#    sale_price  recent_sale_count
# 0       31500                  2
# 1       79500                  0
# 2       15800                  0
# 3      107640                  5
# 4      123240                  3

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

df1.head(3)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
#
#                                        item          color  material  \
# 0  리넨원피스/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름나시/여름원피스  네이비/블랙/베이지/블루        리넨
# 1                트위드원피스/로맨틱원피스/슬림원피스/하객룩원피스      블랙/베이지/골드   폴리에스터/울
# 2             베이식원피스/셔츠원피스/롱셔츠원피스/칼라원피스/롱셔츠    블랙/베이지/아이보리  코튼/폴리에스터
#
#    sale_price  recent_sale_count
# 0       31500                  2
# 1       79500                  0
# 2       15800                  0

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc        0
# category_small_desc         0
# item                        0
# color                   73708
# material                53718
# sale_price                  0
# recent_sale_count           0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302167 entries, 0 to 416486
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  302167 non-null  object
#  1   category_small_desc   302167 non-null  object
#  2   item                  302167 non-null  object
#  3   color                 302167 non-null  object
#  4   material              302167 non-null  object
#  5   sale_price            302167 non-null  int64
#  6   recent_sale_count     302167 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.4+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_07_05')

df1.head(3)
# Out:
#          Time category_middle_desc category_small_desc  \
# 0  2023_07_05                  원피스                롱원피스
# 3  2023_07_05                  원피스                롱원피스
# 4  2023_07_05                  원피스                롱원피스
#
#                                        item          color material  \
# 0  리넨원피스/나시원피스/리넨나시/바캉스룩원피스/롱원피스/여름나시/여름원피스  네이비/블랙/베이지/블루       리넨
# 3                          맥시원피스/롱원피스/도트원피스        네이비/화이트    폴리에스터
# 4              플리츠원피스/맥시원피스/롱원피스/봄원피스/여름원피스             블랙    폴리에스터
#
#    sale_price  recent_sale_count
# 0       31500                  2
# 3      107640                  5
# 4      123240                  3

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230705.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

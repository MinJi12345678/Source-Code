# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 8월 09일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230809.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc  \
# 0                 여성복                  원피스             스퀘어넥원피스
# 1                 여성복                  원피스             스퀘어넥원피스
# 2                 여성복               세트/투피스              세트/투피스
#
#                   item                color  use  material print_pattern  \
# 0  데님원피스/슬림원피스/스퀘어넥원피스                  NaN  NaN     데님/코튼           NaN
# 1                  NaN                   와인  NaN  폴리에스터/코튼             별
# 2             봄정장/세미정장  블랙/베이지/핑크/라이트블루/네이비  NaN  폴리에스터/스판             별
#
#    characteristic             detail  age weight season sensibility  \
# 0             NaN                NaN  NaN    NaN    NaN         NaN
# 1  고급스러운/우아한/국내생산               머메이드  NaN    NaN    NaN         NaN
# 2    부드러운/깔끔한/포멀한  스트레이트핏/7부/원버튼/슬림핏  NaN    NaN    NaN         NaN
#
#    sale_price  recent_sale_count
# 0       36900                  0
# 1       48800                  0
# 2      115000                  0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421168 entries, 0 to 421167
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   421168 non-null  object
#  1   category_middle_desc  421168 non-null  object
#  2   category_small_desc   421168 non-null  object
#  3   item                  343505 non-null  object
#  4   color                 347546 non-null  object
#  5   use                   123022 non-null  object
#  6   material              366567 non-null  object
#  7   print_pattern         194876 non-null  object
#  8   characteristic        262373 non-null  object
#  9   detail                311667 non-null  object
#  10  age                   1763 non-null    object
#  11  weight                24434 non-null   object
#  12  season                380 non-null     object
#  13  sensibility           15381 non-null   object
#  14  sale_price            421168 non-null  int64
#  15  recent_sale_count     421168 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 51.4+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                     77663
# color                    73622
# use                     298146
# material                 54601
# print_pattern           226292
# characteristic          158795
# detail                  109501
# age                     419405
# weight                  396734
# season                  420788
# sensibility             405787
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc                 item  \
# 0                  원피스             스퀘어넥원피스  데님원피스/슬림원피스/스퀘어넥원피스
# 1                  원피스             스퀘어넥원피스                  NaN
# 2               세트/투피스              세트/투피스             봄정장/세미정장
# 3               세트/투피스              세트/투피스                 세미정장
# 4               세트/투피스              세트/투피스                  NaN
#
#                   color      material  sale_price  recent_sale_count
# 0                   NaN         데님/코튼       36900                  0
# 1                    와인      폴리에스터/코튼       48800                  0
# 2   블랙/베이지/핑크/라이트블루/네이비      폴리에스터/스판      115000                  0
# 3                블랙/옐로우           NaN      119000                  0
# 4  블랙/화이트/그레이/라이트블루/네이비  폴리에스터/레이온/실크      169000                  0

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

df1.head(3)
# Out:
#   category_middle_desc category_small_desc                 item  \
# 0                  원피스             스퀘어넥원피스  데님원피스/슬림원피스/스퀘어넥원피스
# 1                  원피스             스퀘어넥원피스              스퀘어넥원피스
# 2               세트/투피스              세트/투피스             봄정장/세미정장
#
#                  color  material  sale_price  recent_sale_count
# 0                  NaN     데님/코튼       36900                  0
# 1                   와인  폴리에스터/코튼       48800                  0
# 2  블랙/베이지/핑크/라이트블루/네이비  폴리에스터/스판      115000                  0

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc        0
# category_small_desc         0
# item                        0
# color                   73622
# material                54601
# sale_price                  0
# recent_sale_count           0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306142 entries, 1 to 421167
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  306142 non-null  object
#  1   category_small_desc   306142 non-null  object
#  2   item                  306142 non-null  object
#  3   color                 306142 non-null  object
#  4   material              306142 non-null  object
#  5   sale_price            306142 non-null  int64
#  6   recent_sale_count     306142 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.7+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_08_09')

df1.head(3)
# Out:
#            Time category_middle_desc category_small_desc  \
# 43   2023_08_09                  원피스                롱원피스
# 278  2023_08_09                  원피스                롱원피스
# 305  2023_08_09                  원피스                롱원피스
#
#                                   item         color  material  sale_price  \
# 43                  피케원피스/데일리원피스/여름원피스  네이비/아이보리/그레이        코튼       38900
# 278                              경량원피스        블랙/베이지     폴리에스터       38800
# 305  빅사이즈원피스/오버핏원피스/롱원피스/슬릿롱원피스/홈웨어원피스    블랙/화이트/그레이  폴리에스터/스판       25900
#
#      recent_sale_count
# 43                   1
# 278                  1
# 305                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230809.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

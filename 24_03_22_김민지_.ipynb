# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 6월 28일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230628.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc  \
# 0                 여성복                  원피스                롱원피스
# 1                 여성복                  원피스                롱원피스
# 2                 여성복                  원피스                롱원피스
#
#                                                 item  \
# 0                                                NaN
# 1  슬림원피스/롱원피스/겨울원피스/이너원피스/브이넥원피스/울원피스/브이넥니트/H라인원피...
# 2                                             하객룩원피스
#
#                       color           use       material print_pattern  \
# 0  아이보리/라이트블루/그레이/베이지/핑크/블랙           NaN            NaN             별
# 1                       NaN  마실룩/여행룩/데일리룩  레이온/폴리에스터/나일론             별
# 2                       NaN          오피스룩       폴리에스터/스판            체크
#
#   characteristic     detail  age weight season sensibility  sale_price  \
# 0          여리여리한  머메이드/볼륨소매  NaN    NaN    NaN         NaN       51200
# 1        탄탄한/편안한        스트링  NaN    NaN    NaN         NaN       36900
# 2        탄탄한/편안한        NaN  NaN    NaN    NaN         NaN       74700
#
#    recent_sale_count
# 0                  0
# 1                  0
# 2                  0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414151 entries, 0 to 414150
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   414151 non-null  object
#  1   category_middle_desc  414151 non-null  object
#  2   category_small_desc   414151 non-null  object
#  3   item                  334973 non-null  object
#  4   color                 340933 non-null  object
#  5   use                   118227 non-null  object
#  6   material              360758 non-null  object
#  7   print_pattern         191119 non-null  object
#  8   characteristic        257364 non-null  object
#  9   detail                304472 non-null  object
#  10  age                   1735 non-null    object
#  11  weight                23306 non-null   object
#  12  season                337 non-null     object
#  13  sensibility           14792 non-null   object
#  14  sale_price            414151 non-null  int64
#  15  recent_sale_count     414151 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 50.6+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                     79178
# color                    73218
# use                     295924
# material                 53393
# print_pattern           223032
# characteristic          156787
# detail                  109679
# age                     412416
# weight                  390845
# season                  413814
# sensibility             399359
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
# 3                  원피스                롱원피스
# 4                  원피스                롱원피스
#
#                                                 item  \
# 0                                                NaN
# 1  슬림원피스/롱원피스/겨울원피스/이너원피스/브이넥원피스/울원피스/브이넥니트/H라인원피...
# 2                                             하객룩원피스
# 3      롱원피스/브이넥원피스/도트원피스/머메이드원피스/언발원피스/셔링원피스/빅사이즈원피스
# 4                                                NaN
#
#                       color       material  sale_price  recent_sale_count
# 0  아이보리/라이트블루/그레이/베이지/핑크/블랙            NaN       51200                  0
# 1                       NaN  레이온/폴리에스터/나일론       36900                  0
# 2                       NaN       폴리에스터/스판       74700                  0
# 3                       NaN          폴리에스터       19500                  0
# 4                        블루             코튼       27000                  0

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

df1.head(3)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
#
#                                                 item  \
# 0                                               롱원피스
# 1  슬림원피스/롱원피스/겨울원피스/이너원피스/브이넥원피스/울원피스/브이넥니트/H라인원피...
# 2                                             하객룩원피스
#
#                       color       material  sale_price  recent_sale_count
# 0  아이보리/라이트블루/그레이/베이지/핑크/블랙            NaN       51200                  0
# 1                       NaN  레이온/폴리에스터/나일론       36900                  0
# 2                       NaN       폴리에스터/스판       74700                  0

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc        0
# category_small_desc         0
# item                        0
# color                   73218
# material                53393
# sale_price                  0
# recent_sale_count           0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300580 entries, 4 to 414148
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  300580 non-null  object
#  1   category_small_desc   300580 non-null  object
#  2   item                  300580 non-null  object
#  3   color                 300580 non-null  object
#  4   material              300580 non-null  object
#  5   sale_price            300580 non-null  int64
#  6   recent_sale_count     300580 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.3+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_06_28')

df1.head(3)
# Out:
#            Time category_middle_desc category_small_desc  \
# 28   2023_06_28                  원피스                롱원피스
# 37   2023_06_28                  원피스                롱원피스
# 111  2023_06_28                  원피스                롱원피스
#
#                                    item        color   material  sale_price  \
# 28                                 롱원피스       블랙/베이지      폴리에스터       18900
# 37   롱원피스/하객룩원피스/볼륨원피스/봄원피스/퍼프원피스/니트원피스  아이보리/블랙/베이지   폴리에스터/코튼       69700
# 111     나시원피스/슬릿원피스/꼬임원피스/플레어원피스/A라인원피스           블랙  레이온/실크/스판       22900
#
#      recent_sale_count
# 28                   1
# 37                   1
# 111                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230628.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 8월 30일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230830.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC  SCLAS                                              GOODS  \
# 0   여성복   원피스  니트원피스                                              니트원피스
# 1   여성복   원피스  니트원피스                     봄원피스/하객룩원피스/베이식원피스/니트원피스/미디원피스
# 2   여성복   원피스  니트원피스  반팔원피스/라운드원피스/배색원피스/하객룩원피스/베이식원피스/반팔니트/배색니트원피스/...
#
#                     COLOR           PRPOS       QLFMT PATT  \
# 0    블루/블랙/민트/라벤더/그레이/베이지             NaN  레이온/실크/나일론  그래픽
# 1  블랙/핑크/카키/라이트블루/그레이/베이지  55사이즈/오피스룩/하객룩         아크릴  NaN
# 2           화이트/베이지/블루/블랙  55사이즈/하객룩/데이트룩         아크릴  NaN
#
#                   CHARTR          DETL  BEM   SLPR  LATST
# 0                 슬림해보이는      볼륨소매/플레어  NaN  79000      0
# 1  고급스러운/저렴한/깔끔한/우아한/텐션감  라운드넥/스트링/슬림핏  NaN  23500      0
# 2                텐션감/심플한           NaN  NaN  27900      1

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422427 entries, 0 to 422426
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   422427 non-null  object
#  1   MLSFC   422427 non-null  object
#  2   SCLAS   422427 non-null  object
#  3   GOODS   346281 non-null  object
#  4   COLOR   348197 non-null  object
#  5   PRPOS   123106 non-null  object
#  6   QLFMT   367675 non-null  object
#  7   PATT    194641 non-null  object
#  8   CHARTR  262352 non-null  object
#  9   DETL    312691 non-null  object
#  10  BEM     15311 non-null   object
#  11  SLPR    422427 non-null  int64
#  12  LATST   422427 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 41.9+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      76146
# COLOR      74230
# PRPOS     299321
# QLFMT      54752
# PATT      227786
# CHARTR    160075
# DETL      109736
# BEM       407116
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC  SCLAS                                              GOODS  \
# 0   원피스  니트원피스                                              니트원피스
# 1   원피스  니트원피스                     봄원피스/하객룩원피스/베이식원피스/니트원피스/미디원피스
# 2   원피스  니트원피스  반팔원피스/라운드원피스/배색원피스/하객룩원피스/베이식원피스/반팔니트/배색니트원피스/...
# 3   원피스  니트원피스                                             데일리원피스
# 4   원피스  니트원피스  슬림니트/브이넥니트/골지니트/연말파티원피스/골지원피스/파티룩원피스/니트원피스/브이넥...
#
#                     COLOR         QLFMT   SLPR  LATST
# 0    블루/블랙/민트/라벤더/그레이/베이지    레이온/실크/나일론  79000      0
# 1  블랙/핑크/카키/라이트블루/그레이/베이지           아크릴  23500      0
# 2           화이트/베이지/블루/블랙           아크릴  27900      1
# 3          네온/아이보리/베이지/골드     폴리에스터/아크릴  37900      0
# 4                  베이지/블랙  스판/폴리에스터/아크릴  27000      0

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    74230
# QLFMT    54752
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306756 entries, 0 to 422426
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   306756 non-null  object
#  1   SCLAS   306756 non-null  object
#  2   GOODS   306756 non-null  object
#  3   COLOR   306756 non-null  object
#  4   QLFMT   306756 non-null  object
#  5   SLPR    306756 non-null  int64
#  6   LATST   306756 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.7+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_08_30')

df1.head(3)
# Out:
#           Time MLSFC  SCLAS  \
# 2   2023_08_30   원피스  니트원피스
# 9   2023_08_30   원피스  니트원피스
# 41  2023_08_30   원피스  니트원피스
#
#                                                 GOODS          COLOR  \
# 2   반팔원피스/라운드원피스/배색원피스/하객룩원피스/베이식원피스/반팔니트/배색니트원피스/...  화이트/베이지/블루/블랙
# 9          U넥원피스/배색니트원피스/배색원피스/슬림원피스/니트원피스/미디원피스/배색니트     그레이/네이비/블랙
# 41                                              니트원피스  베이지/블랙/브라운/그린
#
#            QLFMT   SLPR  LATST
# 2            아크릴  27900      1
# 9            아크릴  29900      1
# 41  레이온/실크/나일론/울  33120      1

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#           Time category_middle_desc category_small_desc  \
# 2   2023_08_30                  원피스               니트원피스
# 9   2023_08_30                  원피스               니트원피스
# 41  2023_08_30                  원피스               니트원피스
#
#                                                  item          color  \
# 2   반팔원피스/라운드원피스/배색원피스/하객룩원피스/베이식원피스/반팔니트/배색니트원피스/...  화이트/베이지/블루/블랙
# 9          U넥원피스/배색니트원피스/배색원피스/슬림원피스/니트원피스/미디원피스/배색니트     그레이/네이비/블랙
# 41                                              니트원피스  베이지/블랙/브라운/그린
#
#         material  sale_price  recent_sale_count
# 2            아크릴       27900                  1
# 9            아크릴       29900                  1
# 41  레이온/실크/나일론/울       33120                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230830.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

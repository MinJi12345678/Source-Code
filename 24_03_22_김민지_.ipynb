# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 5월 10일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230510.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc    item  color  \
# 0                 여성복                  원피스             스퀘어넥원피스  데일리원피스  핑크/블랙
# 1                 여성복                  원피스             스퀘어넥원피스     NaN    오렌지
# 2                 여성복                  원피스             스퀘어넥원피스     NaN     블루
#
#    use material print_pattern characteristic    detail  age weight season  \
# 0  NaN    폴리에스터           NaN    여성스러운/고급스러운  밴딩/셔링/리본  NaN    NaN    NaN
# 1  바캉스       코튼           NaN           비비드한        나시  NaN    NaN    NaN
# 2  바캉스       코튼           NaN           비비드한        나시  NaN    NaN    NaN
#
#   sensibility  sale_price  recent_sale_count
# 0         NaN       22900                  0
# 1         NaN       79900                  0
# 2         NaN       79900                  0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879980 entries, 0 to 879979
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   879980 non-null  object
#  1   category_middle_desc  879980 non-null  object
#  2   category_small_desc   879980 non-null  object
#  3   item                  686513 non-null  object
#  4   color                 722984 non-null  object
#  5   use                   246242 non-null  object
#  6   material              782730 non-null  object
#  7   print_pattern         409327 non-null  object
#  8   characteristic        548911 non-null  object
#  9   detail                605142 non-null  object
#  10  age                   3737 non-null    object
#  11  weight                44132 non-null   object
#  12  season                873 non-null     object
#  13  sensibility           32691 non-null   object
#  14  sale_price            879980 non-null  int64
#  15  recent_sale_count     879980 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 107.4+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                    193467
# color                   156996
# use                     633738
# material                 97250
# print_pattern           470653
# characteristic          331069
# detail                  274838
# age                     876243
# weight                  835848
# season                  879107
# sensibility             847289
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스             스퀘어넥원피스
# 1                  원피스             스퀘어넥원피스
# 2                  원피스             스퀘어넥원피스
# 3                  원피스             스퀘어넥원피스
# 4                  원피스             스퀘어넥원피스
#
#                                         item   color         material  \
# 0                                     데일리원피스   핑크/블랙            폴리에스터
# 1                                        NaN     오렌지               코튼
# 2                                        NaN      블루               코튼
# 3  나시원피스/플로럴원피스/오프숄더원피스/바캉스룩원피스/미디원피스/휴양지원피스  카키/베이지            폴리에스터
# 4                        캐주얼원피스/데일리원피스/여름원피스     NaN  레이온/코튼/폴리에스터/실크
#
#    sale_price  recent_sale_count
# 0       22900                  0
# 1       79900                  0
# 2       79900                  0
# 3       65300                  0
# 4       29900                  0

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

df1.head(3)
# Out:
#   category_middle_desc category_small_desc     item  color material  \
# 0                  원피스             스퀘어넥원피스   데일리원피스  핑크/블랙    폴리에스터
# 1                  원피스             스퀘어넥원피스  스퀘어넥원피스    오렌지       코튼
# 2                  원피스             스퀘어넥원피스  스퀘어넥원피스     블루       코튼
#
#    sale_price  recent_sale_count
# 0       22900                  0
# 1       79900                  0
# 2       79900                  0

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc         0
# category_small_desc          0
# item                         0
# color                   156996
# material                 97250
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 661966 entries, 0 to 879979
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  661966 non-null  object
#  1   category_small_desc   661966 non-null  object
#  2   item                  661966 non-null  object
#  3   color                 661966 non-null  object
#  4   material              661966 non-null  object
#  5   sale_price            661966 non-null  int64
#  6   recent_sale_count     661966 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 40.4+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_05_10')

df1.head(3)
# Out:
#            Time category_middle_desc category_small_desc  \
# 595  2023_05_10                  원피스                롱원피스
# 742  2023_05_10                  원피스                롱원피스
# 934  2023_05_10                  원피스                롱원피스
#
#                                             item         color  material  \
# 595                      간절기원피스/봄원피스/롱원피스/트렌치원피스           베이지        코튼
# 742  빅칼라원피스/하객룩원피스/세일러원피스/캉캉원피스/여름원피스/칼라원피스/롱원피스    네이비/퍼플/베이지        코튼
# 934           롱랩원피스/임부원피스/브이넥롱원피스/롱원피스/랩원피스/여름재킷  베이지/핑크/카키/블랙  스판/폴리에스터
#
#      sale_price  recent_sale_count
# 595       79800                  1
# 742       32980                  1
# 934       29800                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230510.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

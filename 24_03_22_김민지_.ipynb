# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 7월 26일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230726.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   category_large_desc category_middle_desc category_small_desc  \
# 0                 여성복                  원피스                롱원피스
# 1                 여성복                  원피스                롱원피스
# 2                 여성복                  원피스                롱원피스
#
#                                        item          color  \
# 0  여름원피스/바캉스룩원피스/롱원피스/여름나시/나시원피스/리넨원피스/리넨나시  네이비/블루/블랙/베이지
# 1            브이넥원피스/플로럴원피스/랩원피스/리본원피스/시폰원피스          블루/그린
# 2             베이식원피스/칼라원피스/셔츠원피스/롱셔츠/롱셔츠원피스    아이보리/블랙/베이지
#
#                    use  material print_pattern        characteristic  \
# 0                  NaN        리넨           NaN                   NaN
# 1  바캉스/여름필수템/체형커버/바캉스룩     폴리에스터   기하학/플로럴/플로럴  비비드한/하늘거리는/고급스러운/시원한
# 2                  NaN  폴리에스터/코튼           NaN                   NaN
#
#      detail  age weight season sensibility  sale_price  recent_sale_count
# 0  워싱/나시/맥시  NaN    NaN    NaN         NaN       31500                  0
# ...

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424310 entries, 0 to 424309
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_large_desc   424310 non-null  object
#  1   category_middle_desc  424310 non-null  object
#  2   category_small_desc   424310 non-null  object
#  3   item                  345324 non-null  object
#  4   color                 349351 non-null  object
#  5   use                   123311 non-null  object
#  6   material              369411 non-null  object
#  7   print_pattern         196046 non-null  object
#  8   characteristic        264150 non-null  object
#  9   detail                313630 non-null  object
#  10  age                   1796 non-null    object
#  11  weight                24673 non-null   object
#  12  season                374 non-null     object
#  13  sensibility           15277 non-null   object
# ...

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# category_large_desc          0
# category_middle_desc         0
# category_small_desc          0
# item                     78986
# color                    74959
# use                     300999
# material                 54899
# print_pattern           228264
# characteristic          160160
# detail                  110680
# age                     422514
# weight                  399637
# season                  423936
# sensibility             409033
# sale_price                   0
# recent_sale_count            0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10, 11, 12, 13]], axis=1)
df1.head(5)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
# 3                  원피스                롱원피스
# 4                  원피스                롱원피스
#
#                                        item          color  material  \
# 0  여름원피스/바캉스룩원피스/롱원피스/여름나시/나시원피스/리넨원피스/리넨나시  네이비/블루/블랙/베이지        리넨
# 1            브이넥원피스/플로럴원피스/랩원피스/리본원피스/시폰원피스          블루/그린     폴리에스터
# 2             베이식원피스/칼라원피스/셔츠원피스/롱셔츠/롱셔츠원피스    아이보리/블랙/베이지  폴리에스터/코튼
# 3                          도트원피스/롱원피스/맥시원피스         블랙/화이트     폴리에스터
# 4                          도트원피스/롱원피스/맥시원피스        네이비/화이트     폴리에스터
#
#    sale_price  recent_sale_count
# 0       31500                  0
# 1       23800                  1
# 2       15800                  0
# 3      107640                  5
# 4      107640                  0

# %%
df1['item'].fillna(df1['category_small_desc'], inplace = True)

df1.head(3)
# Out:
#   category_middle_desc category_small_desc  \
# 0                  원피스                롱원피스
# 1                  원피스                롱원피스
# 2                  원피스                롱원피스
#
#                                        item          color  material  \
# 0  여름원피스/바캉스룩원피스/롱원피스/여름나시/나시원피스/리넨원피스/리넨나시  네이비/블루/블랙/베이지        리넨
# 1            브이넥원피스/플로럴원피스/랩원피스/리본원피스/시폰원피스          블루/그린     폴리에스터
# 2             베이식원피스/칼라원피스/셔츠원피스/롱셔츠/롱셔츠원피스    아이보리/블랙/베이지  폴리에스터/코튼
#
#    sale_price  recent_sale_count
# 0       31500                  0
# 1       23800                  1
# 2       15800                  0

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc        0
# category_small_desc         0
# item                        0
# color                   74959
# material                54899
# sale_price                  0
# recent_sale_count           0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# category_middle_desc    0
# category_small_desc     0
# item                    0
# color                   0
# material                0
# sale_price              0
# recent_sale_count       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307812 entries, 0 to 424309
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_middle_desc  307812 non-null  object
#  1   category_small_desc   307812 non-null  object
#  2   item                  307812 non-null  object
#  3   color                 307812 non-null  object
#  4   material              307812 non-null  object
#  5   sale_price            307812 non-null  int64
#  6   recent_sale_count     307812 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.8+ MB

# %%
df1 = df1[df1['recent_sale_count'] >= 1]

# %%
df1.insert(0, 'Time', '2023_07_26')

df1.head(3)
# Out:
#          Time category_middle_desc category_small_desc  \
# 1  2023_07_26                  원피스                롱원피스
# 3  2023_07_26                  원피스                롱원피스
# 5  2023_07_26                  원피스                롱원피스
#
#                              item   color material  sale_price  \
# 1  브이넥원피스/플로럴원피스/랩원피스/리본원피스/시폰원피스   블루/그린    폴리에스터       23800
# 3                도트원피스/롱원피스/맥시원피스  블랙/화이트    폴리에스터      107640
# 5    여름원피스/봄원피스/롱원피스/맥시원피스/플리츠원피스      블랙    폴리에스터      123240
#
#    recent_sale_count
# 1                  1
# 3                  5
# 5                  2

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230726.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 8월 16일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230816.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS   MLSFC   SCLAS GOODS                 COLOR              PRPOS  \
# 0   여성복  세트/투피스  세트/투피스  세미정장                옐로우/블랙       출근룩/하객룩/오피스룩
# 1   여성복  세트/투피스  세트/투피스   NaN  화이트/네이비/라이트블루/블랙/그레이  데일리룩/모임룩/하객룩/오피스룩
# 2   여성복  세트/투피스  세트/투피스   NaN                화이트/블랙                NaN
#
#           QLFMT         PATT                CHARTR                       DETL  \
# 0           NaN            별  유니크한/고급스러운/사랑스러운/깔끔한  랩/슬림핏/크롭/핀턱/스트레이트핏/프릴/스트링
# 1  폴리에스터/실크/레이온  스트라이프/스트라이프                   편안한                        슬림핏
# 2           NaN          NaN                   편안한                      V넥/크롭
#
#    BEM    SLPR  LATST
# 0  NaN  119000      0
# 1  NaN  169000      0
# 2  NaN   33000      0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421008 entries, 0 to 421007
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   421008 non-null  object
#  1   MLSFC   421008 non-null  object
#  2   SCLAS   421008 non-null  object
#  3   GOODS   344148 non-null  object
#  4   COLOR   347046 non-null  object
#  5   PRPOS   123087 non-null  object
#  6   QLFMT   366439 non-null  object
#  7   PATT    194615 non-null  object
#  8   CHARTR  262011 non-null  object
#  9   DETL    311616 non-null  object
#  10  BEM     15387 non-null   object
#  11  SLPR    421008 non-null  int64
#  12  LATST   421008 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 41.8+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      76860
# COLOR      73962
# PRPOS     297921
# QLFMT      54569
# PATT      226393
# CHARTR    158997
# DETL      109392
# BEM       405621
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#     MLSFC   SCLAS            GOODS                 COLOR         QLFMT  \
# 0  세트/투피스  세트/투피스             세미정장                옐로우/블랙           NaN
# 1  세트/투피스  세트/투피스              NaN  화이트/네이비/라이트블루/블랙/그레이  폴리에스터/실크/레이온
# 2  세트/투피스  세트/투피스              NaN                화이트/블랙           NaN
# 3  세트/투피스  세트/투피스              NaN             그레이/핑크/블랙           NaN
# 4  세트/투피스  세트/투피스  니트티셔츠/밴딩팬츠/골지니트           그레이/아이보리/블랙           NaN
#
#      SLPR  LATST
# 0  119000      0
# 1  169000      0
# 2   33000      0
# 3   37000      0
# 4   48800      0

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    73962
# QLFMT    54569
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305752 entries, 1 to 421007
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   305752 non-null  object
#  1   SCLAS   305752 non-null  object
#  2   GOODS   305752 non-null  object
#  3   COLOR   305752 non-null  object
#  4   QLFMT   305752 non-null  object
#  5   SLPR    305752 non-null  int64
#  6   LATST   305752 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 18.7+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_08_16')

df1.head(3)
# Out:
#            Time MLSFC SCLAS                     GOODS         COLOR     QLFMT  \
# 181  2023_08_16   원피스  롱원피스                      롱원피스    화이트/베이지/블랙     폴리에스터
# 187  2023_08_16   원피스  롱원피스  베이식원피스/캐주얼원피스/울원피스/겨울원피스  퍼플/베이지/블랙/카키  폴리에스터/코튼
# 192  2023_08_16   원피스  롱원피스              세일러원피스/칼라원피스       아이보리/블랙     폴리에스터
#
#       SLPR  LATST
# 181  47500      1
# 187  21500      1
# 192  31800      1

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#            Time category_middle_desc category_small_desc  \
# 181  2023_08_16                  원피스                롱원피스
# 187  2023_08_16                  원피스                롱원피스
# 192  2023_08_16                  원피스                롱원피스
#
#                          item         color  material  sale_price  \
# 181                      롱원피스    화이트/베이지/블랙     폴리에스터       47500
# 187  베이식원피스/캐주얼원피스/울원피스/겨울원피스  퍼플/베이지/블랙/카키  폴리에스터/코튼       21500
# 192              세일러원피스/칼라원피스       아이보리/블랙     폴리에스터       31800
#
#      recent_sale_count
# 181                  1
# 187                  1
# 192                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230816.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

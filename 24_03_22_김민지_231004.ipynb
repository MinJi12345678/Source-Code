# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_231004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 10월 4일 패션 데이터

# %% [markdown]
# 한글 폰트 설치

# %%
# Linux Package Installation
# !apt-get -qq -y install fonts-nanum > /dev/null

# Delete Cache
# !rm -rf ~/.cache/matplotlib -rf

# %%
import os

os.kill(os.getpid(), 9)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 마이너스 폰트 깨짐 방지
mpl.rcParams['axes.unicode_minus'] = False

# 나눔고딕 전역폰트 지정
plt.rcParams['font.family'] = 'NanumGothic'

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/231004.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC SCLAS                           GOODS           COLOR  \
# 0   여성복   원피스  롱원피스             캐주얼원피스/데일리원피스/박시원피스  베이지/화이트/블랙/네이비
# 1   여성복   원피스  롱원피스                          베이식원피스   차콜/화이트/블랙/베이지
# 2   여성복   원피스  롱원피스  하객룩원피스/겨울원피스/가을원피스/울원피스/데일리원피스    그린/베이지/블랙/핑크
#
#             PRPOS          QLFMT   PATT       CHARTR           DETL  BEM  \
# 0             NaN       폴리에스터/스판    NaN  사랑스러운/여성스러운     워싱/루즈핏/플리츠  NaN
# 1             NaN       폴리에스터/코튼  플로럴/별    심플한/여성스러운             프릴  NaN
# 2  데일리룩/55사이즈/임산부  나일론/폴리에스터/레이온    NaN          심플한  스트레이트핏/루즈핏/9부  NaN
#
#     SLPR  LATST
# 0  15900      0
# 1  21800      0
# 2  31790      0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433263 entries, 0 to 433262
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   433263 non-null  object
#  1   MLSFC   433263 non-null  object
#  2   SCLAS   433263 non-null  object
#  3   GOODS   357711 non-null  object
#  4   COLOR   356056 non-null  object
#  5   PRPOS   125067 non-null  object
#  6   QLFMT   377969 non-null  object
#  7   PATT    199720 non-null  object
#  8   CHARTR  267463 non-null  object
#  9   DETL    318760 non-null  object
#  10  BEM     15549 non-null   object
#  11  SLPR    433263 non-null  int64
#  12  LATST   433263 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 43.0+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      75552
# COLOR      77207
# PRPOS     308196
# QLFMT      55294
# PATT      233543
# CHARTR    165800
# DETL      114503
# BEM       417714
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8,9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC SCLAS                                              GOODS  \
# 0   원피스  롱원피스                                캐주얼원피스/데일리원피스/박시원피스
# 1   원피스  롱원피스                                             베이식원피스
# 2   원피스  롱원피스                     하객룩원피스/겨울원피스/가을원피스/울원피스/데일리원피스
# 3   원피스  롱원피스                                  봄원피스/니트원피스/하객룩원피스
# 4   원피스  롱원피스  나시원피스/롱원피스/신혼여행원피스/여행룩원피스/플리츠원피스/빅사이즈원피스/휴양지원피...
#
#                         COLOR          QLFMT   SLPR  LATST
# 0              베이지/화이트/블랙/네이비       폴리에스터/스판  15900      0
# 1               차콜/화이트/블랙/베이지       폴리에스터/코튼  21800      0
# 2                그린/베이지/블랙/핑크  나일론/폴리에스터/레이온  31790      0
# 3  블랙/네이비/라이트블루/블루/베이지/카키/브라운  나일론/폴리에스터/레이온  33830      0
# 4                베이지/아이보리/네이비             코튼  42000      0

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    77207
# QLFMT    55294
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314444 entries, 0 to 433262
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   314444 non-null  object
#  1   SCLAS   314444 non-null  object
#  2   GOODS   314444 non-null  object
#  3   COLOR   314444 non-null  object
#  4   QLFMT   314444 non-null  object
#  5   SLPR    314444 non-null  int64
#  6   LATST   314444 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 19.2+ MB

# %%
df1[df1['LATST'] >= 1]
# Out:
#        MLSFC  SCLAS                                              GOODS  \
# 140      원피스   롱원피스                               베이식원피스/캐주얼원피스/걸리쉬원피스
# 160      원피스   롱원피스  간절기원피스/기모원피스/루즈핏원피스/여름재킷/임부원피스/겨울원피스/가을원피스/울원피...
# 228      원피스   롱원피스  롱원피스/빅사이즈롱원피스/루즈핏원피스/플리츠원피스/빅사이즈원피스/오버핏원피스/니트원...
# 250      원피스   롱원피스  베이식원피스/프릴원피스/에스닉원피스/롱원피스/아사면원피스/러플원피스/캉캉원피스/코튼...
# 272      원피스   롱원피스                                               롱원피스
# ...      ...    ...                                                ...
# 431804   스커트  데님스커트                     리넨팬츠/데일리스커트/데일리치마바지/치마바지/미니스커트
# 431945   스커트  데님스커트                미디스커트/사선스커트/절개스커트/슬릿스커트/데님스커트/흑청스커트
# 431951   스커트  데님스커트                                              데님스커트
# 432126   스커트  데님스커트                              리넨팬츠/치마바지/가을스커트/데님스커트
# 432170   스커트  데님스커트          가을스커트/겨울스커트/카고스커트/울스커트/간절기스커트/미니스커트/데님스커트
#
#                       COLOR            QLFMT   SLPR  LATST
# ...

# %%
df1.insert(0, 'Time', '2023_10_04')

df1.head(3)
# Out:
#            Time MLSFC SCLAS  \
# 140  2023_10_04   원피스  롱원피스
# 160  2023_10_04   원피스  롱원피스
# 228  2023_10_04   원피스  롱원피스
#
#                                                  GOODS       COLOR  \
# 140                               베이식원피스/캐주얼원피스/걸리쉬원피스  베이지/블랙/그레이
# 160  간절기원피스/기모원피스/루즈핏원피스/여름재킷/임부원피스/겨울원피스/가을원피스/울원피...          블랙
# 228  롱원피스/빅사이즈롱원피스/루즈핏원피스/플리츠원피스/빅사이즈원피스/오버핏원피스/니트원...  그린/아이보리/블랙
#
#                QLFMT   SLPR  LATST
# 140            폴리에스터  23500      2
# 160      폴리에스터/스판/기모  22800      1
# 228  폴리에스터/레이온/스판/실크  33000      1

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#            Time category_middle_desc category_small_desc  \
# 140  2023_10_04                  원피스                롱원피스
# 160  2023_10_04                  원피스                롱원피스
# 228  2023_10_04                  원피스                롱원피스
#
#                                                   item       color  \
# 140                               베이식원피스/캐주얼원피스/걸리쉬원피스  베이지/블랙/그레이
# 160  간절기원피스/기모원피스/루즈핏원피스/여름재킷/임부원피스/겨울원피스/가을원피스/울원피...          블랙
# 228  롱원피스/빅사이즈롱원피스/루즈핏원피스/플리츠원피스/빅사이즈원피스/오버핏원피스/니트원...  그린/아이보리/블랙
#
#             material  sale_price  recent_sale_count
# 140            폴리에스터       23500                  2
# 160      폴리에스터/스판/기모       22800                  1
# 228  폴리에스터/레이온/스판/실크       33000                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/231004.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_230927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 9월 27일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230927.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC SCLAS                                              GOODS  \
# 0   여성복   원피스  롱원피스           리넨원피스/나시원피스/리넨나시/롱원피스/여름나시/여름원피스/바캉스룩원피스
# 1   여성복   원피스  롱원피스  칼라원피스/롱원피스/레이스원피스/셔츠원피스/리본원피스/여름원피스/펀칭원피스/러플원피...
# 2   여성복   원피스  롱원피스                     브이넥원피스/리본원피스/플로럴원피스/시폰원피스/랩원피스
#
#                         COLOR PRPOS  QLFMT       PATT      CHARTR  \
# 0               블루/블랙/네이비/베이지   NaN     리넨        NaN         NaN
# 1  그린/라이트블루/아이보리/베이지/퍼플/핑크/블랙   NaN     코튼        NaN  비침방지/고급스러운
# 2               베이지/그린/블랙/그레이   NaN  폴리에스터  기하학/플로럴/별       찰랑거리는
#
#             DETL  BEM   SLPR  LATST
# 0       나시/맥시/워싱  NaN  31500      1
# 1         펀칭/스트링  NaN  25440      0
# 2  볼륨소매/랩/셔링/스트링  NaN  22800      0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431973 entries, 0 to 431972
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   431973 non-null  object
#  1   MLSFC   431973 non-null  object
#  2   SCLAS   431973 non-null  object
#  3   GOODS   356351 non-null  object
#  4   COLOR   355192 non-null  object
#  5   PRPOS   124842 non-null  object
#  6   QLFMT   376476 non-null  object
#  7   PATT    199192 non-null  object
#  8   CHARTR  266888 non-null  object
#  9   DETL    318130 non-null  object
#  10  BEM     15510 non-null   object
#  11  SLPR    431973 non-null  int64
#  12  LATST   431973 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 42.8+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      75622
# COLOR      76781
# PRPOS     307131
# QLFMT      55497
# PATT      232781
# CHARTR    165085
# DETL      113843
# BEM       416463
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC SCLAS                                              GOODS  \
# 0   원피스  롱원피스           리넨원피스/나시원피스/리넨나시/롱원피스/여름나시/여름원피스/바캉스룩원피스
# 1   원피스  롱원피스  칼라원피스/롱원피스/레이스원피스/셔츠원피스/리본원피스/여름원피스/펀칭원피스/러플원피...
# 2   원피스  롱원피스                     브이넥원피스/리본원피스/플로럴원피스/시폰원피스/랩원피스
# 3   원피스  롱원피스                                   도트원피스/맥시원피스/롱원피스
# 4   원피스  롱원피스                       맥시원피스/롱원피스/여름원피스/플리츠원피스/봄원피스
#
#                         COLOR  QLFMT    SLPR  LATST
# 0               블루/블랙/네이비/베이지     리넨   31500      1
# 1  그린/라이트블루/아이보리/베이지/퍼플/핑크/블랙     코튼   25440      0
# 2               베이지/그린/블랙/그레이  폴리에스터   22800      0
# 3                      블랙/화이트  폴리에스터  107640      2
# 4                          블랙  폴리에스터  123240      0

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    76781
# QLFMT    55497
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 313378 entries, 0 to 431972
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   313378 non-null  object
#  1   SCLAS   313378 non-null  object
#  2   GOODS   313378 non-null  object
#  3   COLOR   313378 non-null  object
#  4   QLFMT   313378 non-null  object
#  5   SLPR    313378 non-null  int64
#  6   LATST   313378 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 19.1+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_10_04')

df1.head(3)
# Out:
#           Time MLSFC SCLAS                                     GOODS  \
# 0   2023_10_04   원피스  롱원피스  리넨원피스/나시원피스/리넨나시/롱원피스/여름나시/여름원피스/바캉스룩원피스
# 3   2023_10_04   원피스  롱원피스                          도트원피스/맥시원피스/롱원피스
# 10  2023_10_04   원피스  롱원피스                        패턴원피스/포인트원피스/여름원피스
#
#              COLOR  QLFMT    SLPR  LATST
# 0    블루/블랙/네이비/베이지     리넨   31500      1
# 3           블랙/화이트  폴리에스터  107640      2
# 10  블루/그린/화이트/아이보리  폴리에스터   23900      1

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#           Time category_middle_desc category_small_desc  \
# 0   2023_10_04                  원피스                롱원피스
# 3   2023_10_04                  원피스                롱원피스
# 10  2023_10_04                  원피스                롱원피스
#
#                                         item           color material  \
# 0   리넨원피스/나시원피스/리넨나시/롱원피스/여름나시/여름원피스/바캉스룩원피스   블루/블랙/네이비/베이지       리넨
# 3                           도트원피스/맥시원피스/롱원피스          블랙/화이트    폴리에스터
# 10                        패턴원피스/포인트원피스/여름원피스  블루/그린/화이트/아이보리    폴리에스터
#
#     sale_price  recent_sale_count
# 0        31500                  1
# 3       107640                  2
# 10       23900                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230927.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# <a href="https://colab.research.google.com/github/MinJi12345678/Source-Code/blob/main/24_03_22_%EA%B9%80%EB%AF%BC%EC%A7%80_230927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2023년 9월 20일 패션 데이터

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 데이터 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
url = '/content/drive/MyDrive/5조/03. 데이터/패션 데이터/230920.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#   LCLAS MLSFC SCLAS                                        GOODS       COLOR  \
# 0   여성복   원피스  롱원피스  롱원피스/리넨원피스/봄원피스/여름원피스/뷔스티에원피스/루즈핏원피스/오버롤스커트   베이지/카키/차콜
# 1   여성복   원피스  롱원피스              롱원피스/하객룩재킷/시스루원피스/하객룩원피스/레이스원피스  아이보리/핑크/블랙
# 2   여성복   원피스  롱원피스                                       베이식원피스          블루
#
#   PRPOS  QLFMT PATT CHARTR    DETL  BEM    SLPR  LATST
# 0   NaN  코튼/리넨  NaN    시원한  맥시/루즈핏  NaN   19800      0
# 1   NaN  폴리에스터  NaN    NaN     NaN  NaN  122400      0
# 2   NaN     코튼  NaN    가벼운     오버롤  NaN   32400      0

# %% [markdown]
# 1) .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429824 entries, 0 to 429823
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   LCLAS   429824 non-null  object
#  1   MLSFC   429824 non-null  object
#  2   SCLAS   429824 non-null  object
#  3   GOODS   353978 non-null  object
#  4   COLOR   353477 non-null  object
#  5   PRPOS   124213 non-null  object
#  6   QLFMT   374397 non-null  object
#  7   PATT    198019 non-null  object
#  8   CHARTR  265818 non-null  object
#  9   DETL    316881 non-null  object
#  10  BEM     15425 non-null   object
#  11  SLPR    429824 non-null  int64
#  12  LATST   429824 non-null  int64
# dtypes: int64(2), object(11)
# memory usage: 42.6+ MB

# %% [markdown]
# 2) 결측치 확인

# %%
df.isnull().sum(axis = 0)
# Out:
# LCLAS          0
# MLSFC          0
# SCLAS          0
# GOODS      75846
# COLOR      76347
# PRPOS     305611
# QLFMT      55427
# PATT      231805
# CHARTR    164006
# DETL      112943
# BEM       414399
# SLPR           0
# LATST          0
# dtype: int64

# %% [markdown]
# 3) 데이터 복사

# %%
df1 = df.copy()

# %% [markdown]
# 4) 불필요 데이터 삭제

# %%
df1 = df1.drop(df1.columns[[0, 5, 7, 8, 9, 10]], axis=1)
df1.head(5)
# Out:
#   MLSFC SCLAS                                        GOODS        COLOR  \
# 0   원피스  롱원피스  롱원피스/리넨원피스/봄원피스/여름원피스/뷔스티에원피스/루즈핏원피스/오버롤스커트    베이지/카키/차콜
# 1   원피스  롱원피스              롱원피스/하객룩재킷/시스루원피스/하객룩원피스/레이스원피스   아이보리/핑크/블랙
# 2   원피스  롱원피스                                       베이식원피스           블루
# 3   원피스  롱원피스           투피스세트/골지원피스/니트원피스/카디건세트/슬림원피스/골지니트  베이지/블랙/아이보리
# 4   원피스  롱원피스                                캐주얼원피스/레터링원피스    베이지/핑크/블랙
#
#            QLFMT    SLPR  LATST
# 0          코튼/리넨   19800      0
# 1          폴리에스터  122400      0
# 2             코튼   32400      0
# 3  아크릴/나일론/폴리에스터   29800      3
# 4       코튼/폴리에스터   29800      0

# %%
df1['GOODS'].fillna(df1['SCLAS'], inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC        0
# SCLAS        0
# GOODS        0
# COLOR    76347
# QLFMT    55427
# SLPR         0
# LATST        0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum(axis = 0)
# Out:
# MLSFC    0
# SCLAS    0
# GOODS    0
# COLOR    0
# QLFMT    0
# SLPR     0
# LATST    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311704 entries, 0 to 429823
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   MLSFC   311704 non-null  object
#  1   SCLAS   311704 non-null  object
#  2   GOODS   311704 non-null  object
#  3   COLOR   311704 non-null  object
#  4   QLFMT   311704 non-null  object
#  5   SLPR    311704 non-null  int64
#  6   LATST   311704 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 19.0+ MB

# %%
df1 = df1[df1['LATST'] >= 1]

# %%
df1.insert(0, 'Time', '2023_10_04')

df1.head(3)
# Out:
#           Time MLSFC SCLAS                                              GOODS  \
# 3   2023_10_04   원피스  롱원피스                 투피스세트/골지원피스/니트원피스/카디건세트/슬림원피스/골지니트
# 11  2023_10_04   원피스  롱원피스                           롱원피스/여름원피스/오피스룩원피스/새틴원피스
# 12  2023_10_04   원피스  롱원피스  롱원피스/반팔원피스/리넨원피스/여름원피스/데일리원피스/캐주얼원피스/베이식원피스/체형...
#
#                              COLOR          QLFMT   SLPR  LATST
# 3                      베이지/블랙/아이보리  아크릴/나일론/폴리에스터  29800      3
# 11           핑크/라이트블루/블루/골드/블랙/베이지          폴리에스터  33000      1
# 12  화이트/핑크/카키/블루/퍼플/블랙/베이지/네이비/브라운             리넨  36000      1

# %%
names = {'MLSFC':'category_middle_desc', 'SCLAS':'category_small_desc', 'GOODS':'item',
                    'COLOR':'color', 'QLFMT':'material', 'SLPR':'sale_price', 'LATST':'recent_sale_count'}

df1.rename(columns = names, inplace = True)
df1.head(3)
# Out:
#           Time category_middle_desc category_small_desc  \
# 3   2023_10_04                  원피스                롱원피스
# 11  2023_10_04                  원피스                롱원피스
# 12  2023_10_04                  원피스                롱원피스
#
#                                                  item  \
# 3                  투피스세트/골지원피스/니트원피스/카디건세트/슬림원피스/골지니트
# 11                           롱원피스/여름원피스/오피스룩원피스/새틴원피스
# 12  롱원피스/반팔원피스/리넨원피스/여름원피스/데일리원피스/캐주얼원피스/베이식원피스/체형...
#
#                              color       material  sale_price  \
# 3                      베이지/블랙/아이보리  아크릴/나일론/폴리에스터       29800
# 11           핑크/라이트블루/블루/골드/블랙/베이지          폴리에스터       33000
# 12  화이트/핑크/카키/블루/퍼플/블랙/베이지/네이비/브라운             리넨       36000
#
#     recent_sale_count
# 3                   3
# 11                  1
# 12                  1

# %%
file_path = '/content/drive/MyDrive/5조/03. 데이터/1차 전처리 패션 데이터/230920.csv'  # 저장할 파일 경로
df1.to_csv(file_path, index=False)

print("CSV 파일이 성공적으로 저장되었습니다.")
# Out:
# CSV 파일이 성공적으로 저장되었습니다.
